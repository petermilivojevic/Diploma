# %%
import itertools as it
import networkx as nx

def vsi_grafi(n, e):
    # Generate all possible edges combinations
    all_edges = list(it.combinations(range(n), 2))
    
    # Check if e is valid
    if e < n-1 or e > len(all_edges):
        raise ValueError("Invalid number of edges for a graph with {} nodes.".format(n))
    
    # Generate all graphs with n nodes and e edges
    graphs = []
    for edges in it.combinations(all_edges, e):
        G = nx.Graph()
        G.add_nodes_from(range(n))
        G.add_edges_from(edges)
        if nx.is_connected(G):
            graphs.append(G)
    
    return graphs

n=7

for i in range(2, n + 1):
    vsota = 0
    for j in range(i-1, int(i*(i-1)/2 + 1)):
        v = 0
        for graf in vsi_grafi(i, j):
            vsota += 1
            v += 1
        print(f'{v} za {i} vozlišč in {j} povezav')
    print(f'{vsota} za {i} vozlišč')
# Out:
# 1 za 2 vozlišč in 1 povezav
# 1 za 2 vozlišč
# 3 za 3 vozlišč in 2 povezav
# 1 za 3 vozlišč in 3 povezav
# 4 za 3 vozlišč
# 16 za 4 vozlišč in 3 povezav
# 15 za 4 vozlišč in 4 povezav
# 6 za 4 vozlišč in 5 povezav
# 1 za 4 vozlišč in 6 povezav
# 38 za 4 vozlišč
# 125 za 5 vozlišč in 4 povezav
# 222 za 5 vozlišč in 5 povezav
# 205 za 5 vozlišč in 6 povezav
# 120 za 5 vozlišč in 7 povezav
# 45 za 5 vozlišč in 8 povezav
# 10 za 5 vozlišč in 9 povezav
# 1 za 5 vozlišč in 10 povezav
# 728 za 5 vozlišč
# 1296 za 6 vozlišč in 5 povezav
# 3660 za 6 vozlišč in 6 povezav
# 5700 za 6 vozlišč in 7 povezav
# 6165 za 6 vozlišč in 8 povezav
# 4945 za 6 vozlišč in 9 povezav
# 2997 za 6 vozlišč in 10 povezav
# 1365 za 6 vozlišč in 11 povezav
# 455 za 6 vozlišč in 12 povezav
# 105 za 6 vozlišč in 13 povezav
# 15 za 6 vozlišč in 14 povezav
# 1 za 6 vozlišč in 15 povezav
# 26704 za 6 vozlišč
# 16807 za 7 vozlišč in 6 povezav
# 68295 za 7 vozlišč in 7 povezav
# 156555 za 7 vozlišč in 8 povezav
# 258125 za 7 vozlišč in 9 povezav
# 331506 za 7 vozlišč in 10 povezav
# 343140 za 7 vozlišč in 11 povezav
# 290745 za 7 vozlišč in 12 povezav
# 202755 za 7 vozlišč in 13 povezav
# 116175 za 7 vozlišč in 14 povezav
# 54257 za 7 vozlišč in 15 povezav
# 20349 za 7 vozlišč in 16 povezav
# 5985 za 7 vozlišč in 17 povezav
# 1330 za 7 vozlišč in 18 povezav
# 210 za 7 vozlišč in 19 povezav
# 21 za 7 vozlišč in 20 povezav
# 1 za 7 vozlišč in 21 povezav
# 1866256 za 7 vozlišč

# %%
def potratno_ravnovesje_max(graf):
    for v1 in graf.nodes:
        for p in list(graf.edges(v1)):
            for v2 in graf.nodes - {v1}:
                testni_graf = graf.copy()
                testni_graf.remove_edge(*p)
                if nx.is_connected(testni_graf):
                    if nx.eccentricity(graf, v1) >= nx.eccentricity(testni_graf, v1):
                        return f"Ni max ravnovesje, vozlišču {v1} se splača izbrisati povezavo {p}"
                testni_graf.add_edge(v1, v2)
                if nx.is_connected(testni_graf):
                    if nx.eccentricity(graf, v1) > nx.eccentricity(testni_graf, v1):
                        return f"Ni max ravnovesje, vozlišču {v1} se splača zamenjati povezavo {p} z povezavo {v1, v2}"
    return 'Je ravnovesje'

n=2

for i in range(2, n + 1):
    vsota = 0
    for j in range(i-1, int(i*(i-1)/2 + 1)):
        v = 0
        for graf in vsi_grafi(i, j):
            if potratno_ravnovesje_max(graf) == 'Je ravnovesje':
                vsota += 1
                v += 1
        print(f'{v} za {i} vozlišč in {j} povezav')
    print(f'{vsota} za {i} vozlišč')
# Out:
# 1 za 2 vozlišč in 1 povezav
# 1 za 2 vozlišč

# %%
import matplotlib.pyplot as plt


def ekzaktno_max(graf):
    def loop_max(graf):
        ravnovesni_graf = graf.copy()
        for v1 in graf.nodes:
            preostale_povezave = list(graf.edges(v1))
            for p in list(graf.edges(v1)):
                preostale_povezave.remove(p)
                for v2 in graf.nodes - {v1}:
                    testni_graf = graf.copy()
                    testni_graf.remove_edge(*p)
                    if nx.is_connected(testni_graf):
                        if nx.eccentricity(graf, v1) >= nx.eccentricity(testni_graf, v1):
                            ravnovesni_graf = testni_graf.copy()
                            return loop_max(ravnovesni_graf)
                    testni_graf.add_edge(v1, v2)
                    if v1 == n - 1 and v2 == n - 2 and not preostale_povezave:
                        if nx.is_connected(testni_graf) and nx.eccentricity(graf, v1) > nx.eccentricity(testni_graf, v1):
                            ravnovesni_graf = testni_graf.copy()
                            return loop_max(ravnovesni_graf)
                        else:
                            return ravnovesni_graf
                    else:
                        if nx.is_connected(testni_graf):
                            if nx.eccentricity(graf, v1) > nx.eccentricity(testni_graf, v1):
                                ravnovesni_graf = testni_graf.copy()
                                return loop_max(ravnovesni_graf)
        # If none of the conditions are met, return the original graph
        
        return ravnovesni_graf

    return loop_max(graf)


print('remove -> add: drevesa')
n=2
for i in range(2, n + 1):
    vsota = 0
    for j in range(i-1, int(i*(i-1)/2 + 1)):
        v = 0
        for graf in vsi_grafi(i, j):
            if nx.number_of_edges(ekzaktno_max(graf)) == i - 1:
                vsota += 1
                v += 1
        print(f'{v} za {i} vozlišč in {j} povezav')
    print(f'{vsota} za {i} vozlišč')
# Out:
# remove -> add: drevesa
# 1 za 2 vozlišč in 1 povezav
# 1 za 2 vozlišč

# %%
n=2
for i in range(2, n + 1):
    for j in range(i-1, int(i*(i-1)/2 + 1)):
        for graf in vsi_grafi(i, j):
            opti = ekzaktno_max(graf)
            if potratno_ravnovesje_max(opti) != 'Je ravnovesje':
                plt.figure(figsize=(8, 8))
                nx.draw(opti, with_labels=True, font_weight='bold', node_color='skyblue', node_size=800, font_size=10)
                plt.show()

# %%
def ekzaktno_max(graf):
    def loop_max(graf):
        ravnovesni_graf = graf.copy()
        for v1 in graf.nodes:
            preostale_povezave = list(graf.edges(v1))
            for p in list(graf.edges(v1)):
                preostale_povezave.remove(p)
                for v2 in graf.nodes - {v1}:
                    testni_graf = graf.copy()
                    testni_graf.remove_edge(*p)
                    testni_graf.add_edge(v1, v2)
                    if nx.is_connected(testni_graf):
                        if nx.eccentricity(graf, v1) > nx.eccentricity(testni_graf, v1):
                            ravnovesni_graf = testni_graf.copy()
                            return loop_max(ravnovesni_graf)
                    testni_graf = graf.copy()
                    testni_graf.remove_edge(*p)
                    if v1 == n - 1 and v2 == n - 2 and not preostale_povezave:
                        if nx.is_connected(testni_graf) and nx.eccentricity(graf, v1) >= nx.eccentricity(testni_graf, v1):
                            ravnovesni_graf = testni_graf.copy()
                            return loop_max(ravnovesni_graf)
                        else:

                            return ravnovesni_graf
                    else:
                        if nx.is_connected(testni_graf):
                            if nx.eccentricity(graf, v1) >= nx.eccentricity(testni_graf, v1):
                                ravnovesni_graf = testni_graf.copy()
                                return loop_max(ravnovesni_graf)
        # If none of the conditions are met, return the original graph

        return ravnovesni_graf

    return loop_max(graf)

print('swap -> remove: drevesa')
n=2
for i in range(2, n + 1):
    vsota = 0
    for j in range(i-1, int(i*(i-1)/2 + 1)):
        v = 0
        for graf in vsi_grafi(i, j):
            if nx.number_of_edges(ekzaktno_max(graf)) == i - 1:
                vsota += 1
                v += 1
        print(f'{v} za {i} vozlišč in {j} povezav')
    print(f'{vsota} za {i} vozlišč')
# Out:
# swap -> remove: drevesa
# 1 za 2 vozlišč in 1 povezav
# 1 za 2 vozlišč

# %%
def ekzaktno_max(graf):
    def loop_max(graf):
        ravnovesni_graf = graf.copy()
        for v1 in graf.nodes:
            preostale_povezave = list(graf.edges(v1))
            for p in list(graf.edges(v1)):
                preostale_povezave.remove(p)
                for v2 in graf.nodes - {v1}:
                    testni_graf = graf.copy()
                    testni_graf.remove_edge(*p)
                    testni_graf.add_edge(v1, v2)
                    if nx.is_connected(testni_graf):
                        if nx.eccentricity(graf, v1) > nx.eccentricity(testni_graf, v1):
                            ravnovesni_graf = testni_graf.copy()
                            return loop_max(ravnovesni_graf)
        for v1 in graf.nodes:
            preostale_povezave = list(graf.edges(v1))
            for p in list(graf.edges(v1)):
                preostale_povezave.remove(p)
                testni_graf = graf.copy()
                testni_graf.remove_edge(*p)
                if v1 == n - 1 and not preostale_povezave:
                    if nx.is_connected(testni_graf) and nx.eccentricity(graf, v1) >= nx.eccentricity(testni_graf, v1):
                        ravnovesni_graf = testni_graf.copy()
                        return loop_max(ravnovesni_graf)
                    else:
                        return ravnovesni_graf
                else:
                    if nx.is_connected(testni_graf):
                        if nx.eccentricity(graf, v1) >= nx.eccentricity(testni_graf, v1):
                            ravnovesni_graf = testni_graf.copy()
                            return loop_max(ravnovesni_graf)
        # If none of the conditions are met, return the original graph

        return ravnovesni_graf

    return loop_max(graf)

print('swap_all -> remove: drevesa')
n=7
for i in range(7, n + 1):
    vsota = 0
    for j in range(i-1, int(i*(i-1)/2 + 1)):
        v = 0
        for graf in vsi_grafi(i, j):
            ravno = ekzaktno_max(graf)
            if nx.number_of_edges(ravno) == i - 1:
                vsota += 1
                v += 1
        print(f'{v} za {i} vozlišč in {j} povezav')
    print(f'{vsota} za {i} vozlišč')
# Out:
# swap_all -> remove: drevesa
# 16807 za 7 vozlišč in 6 povezav
# 47098 za 7 vozlišč in 7 povezav
# 125319 za 7 vozlišč in 8 povezav
# 207053 za 7 vozlišč in 9 povezav
# 255672 za 7 vozlišč in 10 povezav
# 261386 za 7 vozlišč in 11 povezav
# 228026 za 7 vozlišč in 12 povezav
# 164950 za 7 vozlišč in 13 povezav
# 98291 za 7 vozlišč in 14 povezav
# 47701 za 7 vozlišč in 15 povezav
# 18550 za 7 vozlišč in 16 povezav
# 5612 za 7 vozlišč in 17 povezav
# 1267 za 7 vozlišč in 18 povezav
# 200 za 7 vozlišč in 19 povezav
# 21 za 7 vozlišč in 20 povezav
# 0 za 7 vozlišč in 21 povezav
# 1477953 za 7 vozlišč

# %%
import matplotlib.pyplot as plt


def ekzaktno_max(graf):
    def loop_max(graf):
        ravnovesni_graf = graf.copy()
        for v1 in graf.nodes:
            preostale_povezave = list(graf.edges(v1))
            for p in list(graf.edges(v1)):
                preostale_povezave.remove(p)
                testni_graf = graf.copy()
                testni_graf.remove_edge(*p)
                if nx.is_connected(testni_graf):
                    if nx.eccentricity(graf, v1) >= nx.eccentricity(testni_graf, v1):
                        ravnovesni_graf = testni_graf.copy()
                        return loop_max(ravnovesni_graf)
        for v1 in graf.nodes:
            preostale_povezave = list(graf.edges(v1))
            for p in list(graf.edges(v1)):
                preostale_povezave.remove(p)
                for v2 in graf.nodes - {v1}:
                    testni_graf = graf.copy()
                    testni_graf.remove_edge(*p)
                    if nx.is_connected(testni_graf):
                        if nx.eccentricity(graf, v1) >= nx.eccentricity(testni_graf, v1):
                            ravnovesni_graf = testni_graf.copy()
                            return loop_max(ravnovesni_graf)
                    testni_graf.add_edge(v1, v2)
                    if v1 == n - 1 and v2 == n - 2 and not preostale_povezave:
                        if nx.is_connected(testni_graf) and nx.eccentricity(graf, v1) > nx.eccentricity(testni_graf, v1):
                            ravnovesni_graf = testni_graf.copy()
                            return loop_max(ravnovesni_graf)
                        else:
                            return ravnovesni_graf
                    else:
                        if nx.is_connected(testni_graf):
                            if nx.eccentricity(graf, v1) > nx.eccentricity(testni_graf, v1):
                                ravnovesni_graf = testni_graf.copy()
                                return loop_max(ravnovesni_graf)
        # If none of the conditions are met, return the original graph
        
        return ravnovesni_graf

    return loop_max(graf)


print('remove_all -> add: drevesa')
n=7
for i in range(7, n + 1):
    vsota = 0
    for j in range(i-1, int(i*(i-1)/2 + 1)):
        v = 0
        for graf in vsi_grafi(i, j):
            if nx.number_of_edges(ekzaktno_max(graf)) == i - 1:
                vsota += 1
                v += 1
        print(f'{v} za {i} vozlišč in {j} povezav')
    print(f'{vsota} za {i} vozlišč')
# Out:
# remove_all -> add: drevesa
# 16807 za 7 vozlišč in 6 povezav
# 62565 za 7 vozlišč in 7 povezav
# 126906 za 7 vozlišč in 8 povezav
# 187011 za 7 vozlišč in 9 povezav
# 231233 za 7 vozlišč in 10 povezav
# 245093 za 7 vozlišč in 11 povezav
# 219692 za 7 vozlišč in 12 povezav
# 163127 za 7 vozlišč in 13 povezav
# 99190 za 7 vozlišč in 14 povezav
# 48619 za 7 vozlišč in 15 povezav
# 18907 za 7 vozlišč in 16 povezav
# 5684 za 7 vozlišč in 17 povezav
# 1273 za 7 vozlišč in 18 povezav
# 200 za 7 vozlišč in 19 povezav
# 21 za 7 vozlišč in 20 povezav
# 0 za 7 vozlišč in 21 povezav
# 1426328 za 7 vozlišč
